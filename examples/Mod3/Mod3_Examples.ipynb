# %%
10 == 20
# Out:
# False

# %%
10 != 20
# Out:
# True

# %%
10 <= 20
# Out:
# True

# %%
"2" < "9"
# Out:
# True

# %%
"12" < "9"
# Out:
# True

# %%
"12" > "9"
# Out:
# True

# %%
'Hello' == "Hello"
# Out:
# True

# %%
"Hello" < "Zebra"
# Out:
# True

# %%
"hello" < "ZEBRA"
# Out:
# False

# %%
grade:float = 70.0

if grade >= 90:
    print("Grade of A")
elif grade >= 80:
    print("Grade of B")
elif grade >= 70:
    print("Grade of C")
elif grade >= 60:
    print("Grade of D")
else:
    print("you failed")
# Out:
# Grade of C
