# %% [markdown]
# #### Module 2 Practice
# ##### Author: Johang Hernandez
# ##### Version: 1.26.2026.1

# %%
string1:str = "\tWelcome to My Practice Code\n\nThis code shows examples of control characters."

print(string1)
# Out:
# 	Welcome to My Practice Code
#
# This code shows examples of control characters.

# %%
# Print -3.14159 with 2 decimals

n:float = -3.14159

print(f"{n:.2f}")
# Out:
# -3.14

# %%
# Print 31.4159 in exponent form
n:float = 31.4159
print(f"{n:.2e}")
# Out:
# 3.14e+01

# %%
# Q1
2 + 9 * ((3 * 12) - 8) / 10
# Out:
# 27.2

# %%
# Q2
print(f"a: {3 + 2 * 10}")
print(f"b: {2 + 5 * 4 + 3}")
print(f"c: {20 // 2 * 5}")
print(f"d: {2 * 3 ** 2}")
# Out:
# a: 23
# b: 25
# c: 50
# d: 18

# %%
# Q3
print(f"a: {24 // 4 // 2}")
print(f"b: {2 ** 2 ** 3}")
# Out:
# a: 3
# b: 256

# %%
# Q4
print(f"a: {2 + 3.0}")
print("A is a mixed type")
# Out:
# a: 5.0
# A is a mixed type
