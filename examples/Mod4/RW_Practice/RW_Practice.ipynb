# %%
import numpy as np

# %%
cols = np.loadtxt("GLB.Ts+dSST_clean.txt", skiprows=9)
#print(cols)
year = cols[:, 0]
annual_temp_anomaly = cols[:, 13]
annual_temp_anomaly /= 100.0
annual_temp_anomaly
# Out:
# array([-0.09, -0.11, -0.18, -0.28, -0.33, -0.31, -0.36, -0.17, -0.1 ,
#        -0.35, -0.22, -0.27, -0.31, -0.31, -0.23, -0.11, -0.11, -0.27,
#        -0.18, -0.08, -0.16, -0.27, -0.36, -0.46, -0.26, -0.22, -0.38,
#        -0.42, -0.48, -0.43, -0.44, -0.36, -0.35, -0.16, -0.14, -0.36,
#        -0.46, -0.3 , -0.27, -0.27, -0.18, -0.28, -0.27, -0.27, -0.22,
#        -0.1 , -0.21, -0.2 , -0.36, -0.15, -0.09, -0.16, -0.28, -0.12,
#        -0.19, -0.15, -0.02,  0.  , -0.01,  0.13,  0.19,  0.07,  0.09,
#         0.21,  0.09, -0.07, -0.03, -0.11, -0.11, -0.17, -0.07,  0.01,
#         0.08, -0.13, -0.14, -0.19,  0.05,  0.06,  0.03, -0.03,  0.06,
#         0.03,  0.05, -0.2 , -0.11, -0.06, -0.02, -0.08,  0.05,  0.02,
#        -0.08,  0.01,  0.16, -0.07, -0.01, -0.1 ,  0.18,  0.07,  0.16,
#         0.26,  0.32,  0.14,  0.31,  0.16,  0.12,  0.18,  0.32,  0.39,
#         0.27,  0.45,  0.4 ,  0.22,  0.23,  0.31,  0.44,  0.33,  0.46,
# ...

# %%
out_array = np.column_stack((year, annual_temp_anomaly))

np.savetxt("annual_temp_anomaly.txt", out_array, fmt=["%6d", "%.2e"], delimiter="\t")
