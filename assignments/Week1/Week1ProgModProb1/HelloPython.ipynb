# %% [markdown]
# ```plaintext
# Program Name: Hello Python World
# File: HelloPython.ipynb
# Author: C.D. wentworth + Johang Hernandez
# Version: 1.12.2026.0
# ```
# ----
# ```plaintext
# Assignment Details:
#
# Modify the program to first request the user’s first name, and then
# request their last name. The program should then display,
#
#
# Hello firstname lastname
# Welcome to Python!
# ```

# %%
fn:str = input("Type in your first name: ")
ln:str = input("Type in your last name: ")

print(f"Hello {fn} {ln}")
print('Welcome to Python!')
# Out:
# Hello Johang Hernandez
# Welcome to Python!
