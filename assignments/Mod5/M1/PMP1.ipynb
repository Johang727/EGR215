# %% [markdown]
# ## Title: Iris Histogram
# ### Author: C.D. Wentworth + Johang Hernandez
# #### Version: 2.23.2026.1
# > Summary: This program will read in the Iris data set and
#          produce a histogram of one of the measurements.
#
# <details>
# <summary>Revision History</summary>
#     <ul>
#     <li><b>2.23.2026.1</b>: Modified Histogram to display sepal length (cm) rather than petal length.
#     <li><b>7.31.2022.1</b>: base</li>
#     </ui>
# </details>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns 

# Import data as pandas dataframe
df = pd.read_csv('Iris.csv')

# Create a histogram - Seaborn version
sns.histplot(df, x='SepalLengthCm', bins=18, hue='Species')
plt.xlabel("Sepal Length [cm]")
plt.savefig('SepalLengthHist.png', dpi=300)
plt.show()
